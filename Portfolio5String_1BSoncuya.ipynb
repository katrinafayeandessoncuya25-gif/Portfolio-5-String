# %% [markdown]
# # Portfolio 5: String

# %%
print ("Name: Katrina Faye A. Soncuya")
print ("BSChE-1B")
# Out:
# Name: Katrina Faye A. Soncuya
# BSChE-1B

# %%
name = "Juliana"
print (name)
# Out:
# Juliana

# %%
message = "Good day!"
print (message)
# Out:
# Good day!

# %%
name = input ("Enter: ")
# Out:
# Enter:  Katrina

# %%
print (name)
# Out:
# Katrina

# %%
coke = input ("Enter: ")
# Out:
# Enter:  10

# %%
redbull = input ("Enter: ")
# Out:
# Enter:  5

# %%
x = int(coke) - 2
print (x)
# Out:
# 8

# %%
x = int(redbull) - 3
print(x)
# Out:
# 2

# %%
fruit = "avocado"
letter = fruit [1]
print (letter)
# Out:
# v

# %%
fruit = "avocado"
print (len(fruit))
# Out:
# 7

# %%
word = "wisdom"
print (len(word))
# Out:
# 6

# %%
lyrics = "It maybe hard for you to stop and believe"
print (len(lyrics))
# Out:
# 41

# %%
x = coke +
